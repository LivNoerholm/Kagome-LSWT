# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("resdata.txt", delimiter=',')
E = np.genfromtxt("resE.txt")

data
# Out:
# array([[0.0371977 , 0.04069069, 0.03874545, ..., 0.03878109, 0.04070295,
#         0.0371977 ],
#        [0.04073587, 0.04497638, 0.04234645, ..., 0.04239369, 0.04499328,
#         0.04073587],
#        [0.04508758, 0.05027859, 0.04666984, ..., 0.04673327, 0.05030226,
#         0.04508758],
#        ...,
#        [0.00416214, 0.00397124, 0.0040348 , ..., 0.00403347, 0.0039709 ,
#         0.00416214],
#        [0.00408436, 0.00389719, 0.00395944, ..., 0.00395814, 0.00389686,
#         0.00408436],
#        [0.00400875, 0.0038252 , 0.00388618, ..., 0.0038849 , 0.00382487,
#         0.00400875]])

# %%
X = np.linspace(1, 10, 150)
plt.pcolormesh(X, E, data, vmax=15)
