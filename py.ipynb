# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import re

# %%
data = np.genfromtxt("resdata.txt", delimiter=',')
E = np.genfromtxt("resE.txt")

X = np.linspace(0, 100, len(E))

# %%
plt.figure(figsize=(10, 7)) 
plt.pcolormesh(X, E, data, vmax=15)
plt.yticks(np.arange(min(E), max(E), 2))  # adjust step size
plt.colorbar()

# %%
T = np.linspace(0,70,141)

def extract_number(filename):
    return int(re.search(r'\d+', filename).group())

folder_path = 'energyarrays'
sorted_files = sorted(os.listdir(folder_path), key=extract_number)

sorted_files
# Out:
# ['E0.txt',
#  'E5.txt',
#  'E10.txt',
#  'E15.txt',
#  'E20.txt',
#  'E25.txt',
#  'E30.txt',
#  'E35.txt',
#  'E40.txt',
#  'E45.txt',
#  'E50.txt',
#  'E55.txt',
#  'E60.txt',
#  'E65.txt',
#  'E70.txt',
#  'E75.txt',
#  'E80.txt',
#  'E85.txt',
#  'E90.txt',
#  'E95.txt',
#  'E100.txt',
#  'E105.txt',
#  'E110.txt',
#  'E115.txt',
#  'E120.txt',
#  'E125.txt',
#  'E130.txt',
#  'E135.txt',
#  'E140.txt',
#  'E145.txt',
#  'E150.txt',
#  'E155.txt',
#  'E160.txt',
#  'E165.txt',
#  'E170.txt',
#  'E175.txt',
#  'E180.txt',
#  'E185.txt',
#  'E190.txt',
#  'E195.txt',
#  'E200.txt',
#  'E205.txt',
#  'E210.txt',
#  'E215.txt',
#  'E220.txt',
#  'E225.txt',
#  'E230.txt',
#  'E235.txt',
#  'E240.txt',
#  'E245.txt',
#  'E250.txt',
#  'E255.txt',
#  'E260.txt',
#  'E265.txt',
#  'E270.txt',
#  'E275.txt',
#  'E280.txt',
#  'E285.txt',
#  'E290.txt',
#  'E295.txt',
#  'E300.txt',
#  'E305.txt',
#  'E310.txt',
#  'E315.txt',
#  'E320.txt',
#  'E325.txt',
#  'E330.txt',
#  'E335.txt',
#  'E340.txt',
#  'E345.txt',
#  'E350.txt',
#  'E355.txt',
#  'E360.txt',
#  'E365.txt',
#  'E370.txt',
#  'E375.txt',
#  'E380.txt',
#  'E385.txt',
#  'E390.txt',
#  'E395.txt',
#  'E400.txt',
#  'E405.txt',
#  'E410.txt',
#  'E415.txt',
#  'E420.txt',
#  'E425.txt',
#  'E430.txt',
#  'E435.txt',
#  'E440.txt',
#  'E445.txt',
#  'E450.txt',
#  'E455.txt',
#  'E460.txt',
#  'E465.txt',
#  'E470.txt',
#  'E475.txt',
#  'E480.txt',
#  'E485.txt',
#  'E490.txt',
#  'E495.txt',
#  'E500.txt',
#  'E505.txt',
#  'E510.txt',
#  'E515.txt',
#  'E520.txt',
#  'E525.txt',
#  'E530.txt',
#  'E535.txt',
#  'E540.txt',
#  'E545.txt',
#  'E550.txt',
#  'E555.txt',
#  'E560.txt',
#  'E565.txt',
#  'E570.txt',
#  'E575.txt',
#  'E580.txt',
#  'E585.txt',
#  'E590.txt',
#  'E595.txt',
#  'E600.txt',
#  'E605.txt',
#  'E610.txt',
#  'E615.txt',
#  'E620.txt',
#  'E625.txt',
#  'E630.txt',
#  'E635.txt',
#  'E640.txt',
#  'E645.txt',
#  'E650.txt',
#  'E655.txt',
#  'E660.txt',
#  'E665.txt',
#  'E670.txt',
#  'E675.txt',
#  'E680.txt',
#  'E685.txt',
#  'E690.txt',
#  'E695.txt',
#  'E700.txt']

# %%
E_var_list = []
data_array = []
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        data = np.genfromtxt(file_path, delimiter=",")[50:]
        data_array.append(data)
        variance = np.var(data)
        E_var_list.append(variance)

C_v = []
for i in range(len(E_var_list)):
    shc = E_var_list[i]/(T[i]**2)
    C_v.append(shc)

C_v = np.array(C_v)[2:]
C_v
# Out:
# /var/folders/bn/hsprttbn3dz41gj613b58b100000gn/T/ipykernel_3357/2369939136.py:13: RuntimeWarning: divide by zero encountered in scalar divide
#   shc = E_var_list[i]/(T[i]**2)
# array([1.55962694e-07, 2.81838134e-07, 2.13652650e-07, 1.96628508e-07,
#        2.98301196e-07, 1.92518552e-07, 1.83098111e-07, 1.81729777e-07,
#        2.50467446e-07, 2.21072408e-07, 1.89421067e-07, 2.55817886e-07,
#        1.37970853e-07, 1.92519918e-07, 1.95103549e-07, 2.53940515e-07,
#        1.56359651e-07, 1.93594837e-07, 1.95592953e-07, 2.55999442e-07,
#        2.07421582e-07, 1.58461571e-07, 1.38950922e-07, 2.15389095e-07,
#        1.59046624e-07, 1.61863449e-07, 2.30345576e-07, 2.31732916e-07,
#        1.70570276e-07, 2.53253720e-07, 2.33790537e-07, 2.38258080e-07,
#        2.08603370e-07, 1.29517004e-07, 2.03381736e-07, 1.96022263e-07,
#        2.46120761e-07, 2.72071013e-07, 2.37034468e-07, 2.72870419e-07,
#        1.36188168e-07, 1.20477714e-07, 2.33443955e-07, 1.72297907e-07,
#        2.41681163e-07, 2.17919916e-07, 1.81741854e-07, 1.44228025e-07,
#        2.03932625e-07, 2.06722300e-07, 2.67848172e-07, 2.36916093e-07,
#        2.36113368e-07, 2.69613753e-07, 2.25040045e-07, 2.16948208e-07,
#        2.29707125e-07, 2.19217809e-07, 2.27616479e-07, 1.93580742e-07,
#        2.81035123e-07, 2.11752867e-07, 2.58362630e-07, 2.31930326e-07,
#        3.06003902e-07, 1.88676333e-07, 2.26158850e-07, 1.75397184e-07,
#        2.90373166e-07, 2.99918562e-07, 2.38862118e-07, 2.37159931e-07,
#        2.78524854e-07, 2.10842255e-07, 1.96090309e-07, 3.11295939e-07,
#        2.72242579e-07, 2.61636896e-07, 2.79136263e-07, 3.43084289e-07,
#        3.82193536e-07, 3.02551753e-07, 3.25854661e-07, 2.75780749e-07,
#        2.71758772e-07, 1.96121814e-07, 4.15806830e-07, 1.53216051e-07,
#        4.21425371e-07, 4.31198465e-07, 2.53634930e-07, 3.01963875e-07,
#        4.59095446e-07, 3.81699671e-07, 3.43228108e-07, 3.60023242e-07,
#        3.34963537e-07, 2.42597990e-07, 2.47201654e-07, 3.41383045e-07,
#        2.65227302e-07, 3.09045306e-07, 3.24830057e-07, 4.34962908e-07,
#        5.72297891e-07, 3.37671583e-07, 1.97726689e-07, 3.03164147e-07,
#        5.95184122e-07, 3.56260073e-07, 2.57308911e-07, 2.56515761e-07,
#        6.53727384e-07, 3.84035034e-07, 2.80030439e-07, 3.30791862e-07,
#        2.30489280e-07, 3.87314117e-07, 1.83455385e-07, 1.66703181e-07,
#        2.95901710e-07, 2.39236336e-07, 2.33851850e-07, 1.85548338e-07,
#        2.02272170e-07, 2.17844034e-07, 1.31370684e-07, 3.45560335e-07,
#        2.26751251e-07, 1.59824860e-07, 2.03690789e-07, 2.09717592e-07,
#        2.04706100e-07, 1.66719254e-07, 1.70374226e-07, 2.27732608e-07,
#        1.29353339e-07, 1.43784537e-07, 1.34530517e-07])

# %%
plt.figure(figsize=(8,5))
plt.plot(T[2:], C_v)
plt.xlabel('Temperature (T)')
plt.ylabel('Specific Heat (C_v)')
plt.title('Specific Heat vs Temperature')
plt.grid()
plt.show()

# %%
mean_Es = []
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        data = np.genfromtxt(file_path, delimiter=",")[55:]
        mean_E = np.mean(data)
        mean_Es.append(mean_E)
plt.figure(figsize=(8,5))
plt.plot(T, mean_Es)
plt.xlabel('Temperature (T)')
plt.ylabel('Mean Energy (E)')
plt.title('Mean Energy vs Temperature')

dE_dt = np.gradient(mean_Es, T)
plt.figure(figsize=(8,5))
plt.plot(T, dE_dt)
plt.xlabel('Temperature (T)')
plt.ylabel('dE/dT')
plt.title('Derivative of Mean Energy vs Temperature')
# Out:
# Text(0.5, 1.0, 'Derivative of Mean Energy vs Temperature')

# %%
y = np.genfromtxt("E15.txt", delimiter=',')[1:]
x = np.linspace(0, 20, len(y))

plt.plot(x,y)
print(len(y))
# Out:
# 100
