# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import re

# %%
data = np.genfromtxt("resdata.txt", delimiter=',')
E = np.genfromtxt("resE.txt")

X = np.linspace(0, 100, len(E))

# %%
plt.figure(figsize=(10, 7)) 
plt.pcolormesh(X, E, data, vmax=15)
plt.yticks(np.arange(min(E), max(E), 2))  # adjust step size
plt.colorbar()

# %%
T = np.linspace(0,70,71)

def extract_number(filename):
    return int(re.search(r'\d+', filename).group())

folder_path = 'energyarrays'
sorted_files = sorted(os.listdir(folder_path), key=extract_number)

sorted_files
# Out:
# ['E0.txt',
#  'E10.txt',
#  'E20.txt',
#  'E30.txt',
#  'E40.txt',
#  'E50.txt',
#  'E60.txt',
#  'E70.txt',
#  'E80.txt',
#  'E90.txt',
#  'E100.txt',
#  'E110.txt',
#  'E120.txt',
#  'E130.txt',
#  'E140.txt',
#  'E150.txt',
#  'E160.txt',
#  'E170.txt',
#  'E180.txt',
#  'E190.txt',
#  'E200.txt',
#  'E210.txt',
#  'E220.txt',
#  'E230.txt',
#  'E240.txt',
#  'E250.txt',
#  'E260.txt',
#  'E270.txt',
#  'E280.txt',
#  'E290.txt',
#  'E300.txt',
#  'E310.txt',
#  'E320.txt',
#  'E330.txt',
#  'E340.txt',
#  'E350.txt',
#  'E360.txt',
#  'E370.txt',
#  'E380.txt',
#  'E390.txt',
#  'E400.txt',
#  'E410.txt',
#  'E420.txt',
#  'E430.txt',
#  'E440.txt',
#  'E450.txt',
#  'E460.txt',
#  'E470.txt',
#  'E480.txt',
#  'E490.txt',
#  'E500.txt',
#  'E510.txt',
#  'E520.txt',
#  'E530.txt',
#  'E540.txt',
#  'E550.txt',
#  'E560.txt',
#  'E570.txt',
#  'E580.txt',
#  'E590.txt',
#  'E600.txt',
#  'E610.txt',
#  'E620.txt',
#  'E630.txt',
#  'E640.txt',
#  'E650.txt',
#  'E660.txt',
#  'E670.txt',
#  'E680.txt',
#  'E690.txt',
#  'E700.txt']

# %%
E_var_list = []
data_array = []
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        data = np.genfromtxt(file_path, delimiter=",")[10:]
        data_array.append(data)
        variance = np.var(data)
        E_var_list.append(variance)

C_v = []
for i in range(len(E_var_list)):
    shc = E_var_list[i]/(T[i]**2)
    C_v.append(shc)

C_v
# Out:
# /var/folders/bn/hsprttbn3dz41gj613b58b100000gn/T/ipykernel_6568/3527249974.py:13: RuntimeWarning: divide by zero encountered in scalar divide
#   shc = E_var_list[i]/(T[i]**2)
# [np.float64(inf),
#  np.float64(1.556207294938486e-07),
#  np.float64(1.8738159800453997e-07),
#  np.float64(2.87526247161799e-07),
#  np.float64(1.8639130260140123e-07),
#  np.float64(2.5373853920611466e-07),
#  np.float64(1.7579914801965421e-07),
#  np.float64(1.5837782591608513e-07),
#  np.float64(1.9012910281890954e-07),
#  np.float64(2.1611799886325495e-07),
#  np.float64(1.8554233692014161e-07),
#  np.float64(2.1509871885236573e-07),
#  np.float64(1.4892850223195263e-07),
#  np.float64(1.7478698099660432e-07),
#  np.float64(2.243864503890825e-07),
#  np.float64(1.8704708619290576e-07),
#  np.float64(2.00233213451788e-07),
#  np.float64(2.2487730067755538e-07),
#  np.float64(2.681116745241618e-07),
#  np.float64(2.629544618468995e-07),
#  np.float64(2.3960841564704676e-07),
#  np.float64(1.5343787566246515e-07),
#  np.float64(2.712213252018805e-07),
#  np.float64(2.9135559551518015e-07),
#  np.float64(2.2481677034481343e-07),
#  np.float64(2.384166374123961e-07),
#  np.float64(2.4430026977341695e-07),
#  np.float64(2.567119937310225e-07),
#  np.float64(2.340785703606768e-07),
#  np.float64(2.236099338705141e-07),
#  np.float64(2.4684028893916747e-07),
#  np.float64(2.726483159524161e-07),
#  np.float64(2.634359128444352e-07),
#  np.float64(2.777719287749926e-07),
#  np.float64(2.869414057055287e-07),
#  np.float64(2.2256898055232162e-07),
#  np.float64(2.5850175124112756e-07),
#  np.float64(2.402520395773882e-07),
#  np.float64(2.622943596575533e-07),
#  np.float64(2.1400739035186503e-07),
#  np.float64(2.353184192855791e-07),
#  np.float64(3.015255565210227e-07),
#  np.float64(3.141977113638927e-07),
#  np.float64(2.7515489526203975e-07),
#  np.float64(4.5608783371873136e-07),
#  np.float64(4.294671637482619e-07),
#  np.float64(3.2579804396383425e-07),
#  np.float64(4.2417167589130943e-07),
#  np.float64(3.4991150768301735e-07),
#  np.float64(3.16885330118323e-07),
#  np.float64(2.4414795633244404e-07),
#  np.float64(2.5962932684479264e-07),
#  np.float64(2.941700331417672e-07),
#  np.float64(4.4540787007266184e-07),
#  np.float64(2.8143307681705983e-07),
#  np.float64(7.628158262124643e-07),
#  np.float64(3.739048179879607e-07),
#  np.float64(6.169006980925374e-07),
#  np.float64(1.1040575657874453e-06),
#  np.float64(4.990043744804697e-07),
#  np.float64(1.9613367837884692e-07),
#  np.float64(2.537030981963509e-07),
#  np.float64(2.509408482431448e-07),
#  np.float64(1.618132773317872e-07),
#  np.float64(1.8843920734080357e-07),
#  np.float64(2.8010441695186694e-07),
#  np.float64(2.072579110047137e-07),
#  np.float64(2.1369758540216305e-07),
#  np.float64(1.6708023447536128e-07),
#  np.float64(1.3397268707897813e-07),
#  np.float64(1.619987746486672e-07)]

# %%
plt.figure(figsize=(8,5))
plt.plot(T, C_v)

# %%
y = np.genfromtxt("E380.txt", delimiter=',')
x = np.linspace(0, 20, len(y))

plt.plot(x,y)
