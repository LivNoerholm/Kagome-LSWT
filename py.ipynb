# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import re

# %%
data = np.genfromtxt("resdata.txt", delimiter=',')
E = np.genfromtxt("resE.txt")

X = np.linspace(0, 100, len(E))

# %%
plt.figure(figsize=(10, 7)) 
plt.pcolormesh(X, E, data, vmax=15)
plt.yticks(np.arange(min(E), max(E), 2))  # adjust step size
plt.colorbar()

# %%
T = np.linspace(0,70,141)

def extract_number(filename):
    return int(re.search(r'\d+', filename).group())

folder_path = 'energyarrays'
sorted_files = sorted(os.listdir(folder_path), key=extract_number)

sorted_files
# Out:
# ['E0.txt',
#  'E5.txt',
#  'E10.txt',
#  'E15.txt',
#  'E20.txt',
#  'E25.txt',
#  'E30.txt',
#  'E35.txt',
#  'E40.txt',
#  'E45.txt',
#  'E50.txt',
#  'E55.txt',
#  'E60.txt',
#  'E65.txt',
#  'E70.txt',
#  'E75.txt',
#  'E80.txt',
#  'E85.txt',
#  'E90.txt',
#  'E95.txt',
#  'E100.txt',
#  'E105.txt',
#  'E110.txt',
#  'E115.txt',
#  'E120.txt',
#  'E125.txt',
#  'E130.txt',
#  'E135.txt',
#  'E140.txt',
#  'E145.txt',
#  'E150.txt',
#  'E155.txt',
#  'E160.txt',
#  'E165.txt',
#  'E170.txt',
#  'E175.txt',
#  'E180.txt',
#  'E185.txt',
#  'E190.txt',
#  'E195.txt',
#  'E200.txt',
#  'E205.txt',
#  'E210.txt',
#  'E215.txt',
#  'E220.txt',
#  'E225.txt',
#  'E230.txt',
#  'E235.txt',
#  'E240.txt',
#  'E245.txt',
#  'E250.txt',
#  'E255.txt',
#  'E260.txt',
#  'E265.txt',
#  'E270.txt',
#  'E275.txt',
#  'E280.txt',
#  'E285.txt',
#  'E290.txt',
#  'E295.txt',
#  'E300.txt',
#  'E305.txt',
#  'E310.txt',
#  'E315.txt',
#  'E320.txt',
#  'E325.txt',
#  'E330.txt',
#  'E335.txt',
#  'E340.txt',
#  'E345.txt',
#  'E350.txt',
#  'E355.txt',
#  'E360.txt',
#  'E365.txt',
#  'E370.txt',
#  'E375.txt',
#  'E380.txt',
#  'E385.txt',
#  'E390.txt',
#  'E395.txt',
#  'E400.txt',
#  'E405.txt',
#  'E410.txt',
#  'E415.txt',
#  'E420.txt',
#  'E425.txt',
#  'E430.txt',
#  'E435.txt',
#  'E440.txt',
#  'E445.txt',
#  'E450.txt',
#  'E455.txt',
#  'E460.txt',
#  'E465.txt',
#  'E470.txt',
#  'E475.txt',
#  'E480.txt',
#  'E485.txt',
#  'E490.txt',
#  'E495.txt',
#  'E500.txt',
#  'E505.txt',
#  'E510.txt',
#  'E515.txt',
#  'E520.txt',
#  'E525.txt',
#  'E530.txt',
#  'E535.txt',
#  'E540.txt',
#  'E545.txt',
#  'E550.txt',
#  'E555.txt',
#  'E560.txt',
#  'E565.txt',
#  'E570.txt',
#  'E575.txt',
#  'E580.txt',
#  'E585.txt',
#  'E590.txt',
#  'E595.txt',
#  'E600.txt',
#  'E605.txt',
#  'E610.txt',
#  'E615.txt',
#  'E620.txt',
#  'E625.txt',
#  'E630.txt',
#  'E635.txt',
#  'E640.txt',
#  'E645.txt',
#  'E650.txt',
#  'E655.txt',
#  'E660.txt',
#  'E665.txt',
#  'E670.txt',
#  'E675.txt',
#  'E680.txt',
#  'E685.txt',
#  'E690.txt',
#  'E695.txt',
#  'E700.txt']

# %%
E_var_list = []
data_array = []
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        data = np.genfromtxt(file_path, delimiter=",")[5:]
        data_array.append(data)
        variance = np.var(data)
        E_var_list.append(variance)

C_v = []
for i in range(len(E_var_list)):
    shc = E_var_list[i]/(T[i]**2)
    C_v.append(shc)
# Out:
# /var/folders/bn/hsprttbn3dz41gj613b58b100000gn/T/ipykernel_3269/2700437707.py:13: RuntimeWarning: divide by zero encountered in scalar divide
#   shc = E_var_list[i]/(T[i]**2)

# %%
plt.figure(figsize=(8,5))
plt.plot(T[2:], C_v[2:])
plt.xlabel('Temperature (T)')
plt.ylabel('Specific Heat (C_v)')
plt.title('Specific Heat vs Temperature')
plt.grid()
plt.show()

print(T[110], "\n", C_v[110])
# Out:
# 55.0
#  8.553535272370054e-07

# %%
mean_Es = []
for filename in sorted_files:
    file_path = os.path.join(folder_path, filename)
    if os.path.isfile(file_path):
        data = np.genfromtxt(file_path, delimiter=",")[5:]
        mean_E = np.mean(data)
        mean_Es.append(mean_E)
plt.figure(figsize=(8,5))
plt.plot(T, mean_Es)
plt.xlabel('Temperature (T)')
plt.ylabel('Mean Energy (E)')
plt.title('Mean Energy vs Temperature')

dE_dt = np.gradient(mean_Es, T)
plt.figure(figsize=(8,5))
plt.plot(T, dE_dt)
plt.xlabel('Temperature (T)')
plt.ylabel('dE/dT')
plt.title('Derivative of Mean Energy vs Temperature')

print(T[110], "\n", dE_dt[110])
# Out:
# 55.0
#  0.26345651703521256
